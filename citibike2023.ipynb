# %%
import pandas as pd

# Cargar los archivos CSV en DataFrames
df1 = pd.read_csv('JC-202301-citibike-tripdata.csv')
df2 = pd.read_csv('JC-202302-citibike-tripdata.csv')
df3 = pd.read_csv('JC-202303-citibike-tripdata.csv')
df4 = pd.read_csv('JC-202304-citibike-tripdata.csv')
df5 = pd.read_csv('JC-202305-citibike-tripdata.csv')
df6 = pd.read_csv('JC-202306-citibike-tripdata.csv')
df7 = pd.read_csv('JC-202307-citibike-tripdata.csv')
df8 = pd.read_csv('JC-202308-citibike-tripdata.csv')
df9 = pd.read_csv('JC-202309-citibike-tripdata.csv')
# Combinar DataFrames (puedes usar merge o concat según tus necesidades)
combined_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9], ignore_index=True)

# %%
combined_df.to_csv('Citibike_data_2023.csv', index=False)

# %%
combined_df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       0905B18B365C9D20   classic_bike  2023-01-28 09:18:10
# 1       B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12
# 2       5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04
# 3       E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08
# 4       323165780CA0734B   classic_bike  2023-01-21 20:44:09
# ...                  ...            ...                  ...
# 756936  A2112D905D1B5FB9  electric_bike  2023-09-05 18:31:42
# 756937  2C9D64FF1B8C44C8   classic_bike  2023-09-25 08:36:13
# 756938  4F4E24251BBAB45E   classic_bike  2023-09-19 07:55:23
# 756939  BB6F0D74150403AC   classic_bike  2023-09-14 07:50:23
# 756940  755AE0D4205C0306   classic_bike  2023-09-22 06:52:07
#
#                    ended_at                        start_station_name  \
# 0       2023-01-28 09:28:52  Hoboken Terminal - Hudson St & Hudson Pl
# 1       2023-01-23 20:18:27  Hoboken Terminal - Hudson St & Hudson Pl
# ...
